# %% [markdown]
# ## Task
#
# In this compulsory task you will clean the country column and parse the date column in the **store_income_data_task.csv** file.

# %%
# Libraries
import pandas as pd
import numpy as np
import fuzzywuzzy
from fuzzywuzzy import process
import chardet
# Out:
# c:\Users\Mandy\AppData\Local\Programs\Python\Python312\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# Load up store_income_data.csv
df = pd.read_csv('store_income_data_task.csv')

df.head(5)
# Out:
#    id                   store_name         store_email  department  \
# 0   1   Cullen/Frost Bankers, Inc.                 NaN    Clothing
# 1   2          Nordson Corporation                 NaN       Tools
# 2   3        Stag Industrial, Inc.                 NaN      Beauty
# 3   4          FIRST REPUBLIC BANK  ecanadine3@fc2.com  Automotive
# 4   5  Mercantile Bank Corporation                 NaN        Baby
#
#          income date_measured          country
# 0  $54438554.24      4-2-2006   United States/
# 1  $41744177.01      4-1-2006          Britain
# 2  $36152340.34     12-9-2003    United States
# 3   $8928350.04      8-5-2006         Britain/
# 4  $33552742.32     21-1-1973   United Kingdom

# %% [markdown]
# 1. Take a look at all the unique values in the "country" column. Then, convert the column to lowercase and remove any trailing white spaces.

# %%
countries = df['country'].unique()
print(f"There are {len(countries)} unique countries")
countries
# Out:
# There are 77 unique countries
# array(['United States/', 'Britain', ' United States', 'Britain/',
#        ' United Kingdom', 'U.K.', 'SA ', 'U.K/', 'America',
#        'United Kingdom', nan, 'united states', ' S.A.', 'England ', 'UK',
#        'S.A./', 'ENGLAND', 'BRITAIN', 'U.K', 'U.K ', 'America/', 'SA.',
#        'S.A. ', 'u.k', 'uk', ' ', 'UK.', 'England/', 'england',
#        ' Britain', 'united states of america', 'UK/', 'SA/', 'SA',
#        'England.', 'UNITED KINGDOM', 'America.', 'S.A..', 's.a.', ' U.K',
#        ' United States of America', 'Britain ', 'England', ' SA',
#        'United States of America.', 'United States of America/',
#        'United States.', 's. africasouth africa', ' England',
#        'United Kingdom ', 'United States of America ', ' UK',
#        'united kingdom', 'AMERICA', 'America ',
#        'UNITED STATES OF AMERICA', ' S. AfricaSouth Africa', 'america',
#        'S. AFRICASOUTH AFRICA', 'Britain.', '/', 'United Kingdom.',
#        'United States', ' America', 'UNITED STATES', 'sa',
#        'United States of America', 'UK ', 'United States ',
#        'S. AfricaSouth Africa/', 'S.A.', 'United Kingdom/',
#        'S. AfricaSouth Africa ', 'S. AfricaSouth Africa.',
#        'S. AfricaSouth Africa', '.', 'britain'], dtype=object)

# %%
df.country = df.country.str.strip()
df.country = df.country.str.lower()
df['country'].unique()
# Out:
# array(['united states/', 'britain', 'united states', 'britain/',
#        'united kingdom', 'u.k.', 'sa', 'u.k/', 'america', nan, 's.a.',
#        'england', 'uk', 's.a./', 'u.k', 'america/', 'sa.', '', 'uk.',
#        'england/', 'united states of america', 'uk/', 'sa/', 'england.',
#        'america.', 's.a..', 'united states of america.',
#        'united states of america/', 'united states.',
#        's. africasouth africa', 'britain.', '/', 'united kingdom.',
#        's. africasouth africa/', 'united kingdom/',
#        's. africasouth africa.', '.'], dtype=object)

# %% [markdown]
# 2. Note that there should only be three separate countries. Eliminate all variations, so that 'South Africa', 'United Kingdom' and 'United States' are the only three countries.

# %%
# Function to replace rows in the provided column of the provided DataFrame
# that match the provided string above the provided ratio with the provided string
def replace_matches_in_column(df, column, string_to_match, min_ratio = 90):
    # get a list of unique strings
    strings = df[column].unique()
    
    # Get the top 10 closest matches to our input string
    matches = fuzzywuzzy.process.extract(string_to_match, strings, 
                                         limit=10, scorer=fuzzywuzzy.fuzz.token_sort_ratio)

    # Only get matches with a ratio > 90
    close_matches = [matches[0] for matches in matches if matches[1] >= min_ratio]

    # Get the rows of all the close matches in our dataframe
    rows_with_matches = df[column].isin(close_matches)

    # Replace all rows with close matches with the input matches 
    df.loc[rows_with_matches, column] = string_to_match
    
    # Let us know when the function is done
    print("All done!")

# %%
replace_matches_in_column(df=df, column='country', string_to_match="uk")
replace_matches_in_column(df=df, column='country', string_to_match="u.k.") 
replace_matches_in_column(df=df, column='country', string_to_match="england") 
replace_matches_in_column(df=df, column='country', string_to_match="united kingdom")
replace_matches_in_column(df=df, column='country', string_to_match="united states")
replace_matches_in_column(df=df, column='country', string_to_match="united states of america")
replace_matches_in_column(df=df, column='country', string_to_match="south africa")
replace_matches_in_column(df=df, column='country', string_to_match="britain")
replace_matches_in_column(df=df, column='country', string_to_match="america")
replace_matches_in_column(df=df, column='country', string_to_match="s.a.")
replace_matches_in_column(df=df, column='country', string_to_match="sa")
replace_matches_in_column(df=df, column='country', string_to_match="s. africasouth africa")
# Out:
# All done!
# All done!
# All done!
# All done!
# All done!
# All done!
# All done!
# All done!
# All done!
# All done!
# All done!
# All done!

# %%
df['country'] = df['country'].str.replace('u.k.', 'united kingdom')
df['country'] = df['country'].str.replace('uk', 'united kingdom')
df['country'] = df['country'].str.replace('britain', 'united kingdom')
df['country'] = df['country'].str.replace('england', 'united kingdom')
df['country'] = df['country'].str.replace('united states of america', 'united states')
df['country'] = df['country'].str.replace('america', 'united states')
df['country'] = df['country'].str.replace('sa', 'south africa')
df['country'] = df['country'].str.replace('s.a.', 'south africa')
df['country'] = df['country'].str.replace('s. africasouth africa', 'south africa')

# %%
print(df.country.unique())
len(df.country.unique())
# Out:
# ['united states' 'united kingdom' 'south africa' nan '' '/' '.']
# 7

# %% [markdown]
# 3. Create a new column called `days_ago` in the DataFrame that is a copy of the 'date_measured' column but instead it is a number that shows how many days ago it was measured from the current date. Note that the current date can be obtained using `datetime.date.today()`.

# %%
df['date_measured'] = pd.to_datetime(df['date_measured'], format='%d-%m-%Y')

# %%
from datetime import datetime

print('Data type:')
print(f"datetime.today(): {type(datetime.today())}")
print(f"df['date_measured']: {df['date_measured'].dtype}")

df['days_ago'] = (datetime.today() - df['date_measured']).dt.days

df.head(10)
# Out:
# Data type:
# datetime.today(): <class 'datetime.datetime'>
# df['date_measured']: datetime64[ns]
#    id                            store_name               store_email  \
# 0   1            Cullen/Frost Bankers, Inc.                       NaN
# 1   2                   Nordson Corporation                       NaN
# 2   3                 Stag Industrial, Inc.                       NaN
# 3   4                   FIRST REPUBLIC BANK        ecanadine3@fc2.com
# 4   5           Mercantile Bank Corporation                       NaN
# 5   6  Auburn National Bancorporation, Inc.   ccaldeyroux5@dion.ne.jp
# 6   7           Interlink Electronics, Inc.  orodenborch6@skyrock.com
# 7   8         Tallgrass Energy Partners, LP                       NaN
# 8   9                        Tronox Limited                       NaN
# 9  10                        Synopsys, Inc.   lcancellieri9@tmall.com
#
#     department        income date_measured         country  days_ago
# 0     Clothing  $54438554.24    2006-02-04   united states      6649
# 1        Tools  $41744177.01    2006-01-04  united kingdom      6680
# 2       Beauty  $36152340.34    2003-09-12   united states      7525
# 3   Automotive   $8928350.04    2006-05-08  united kingdom      6556
# 4         Baby  $33552742.32    1973-01-21  united kingdom     18716
# 5      Grocery  $69798987.04    1999-09-19  united kingdom      8979
# 6       Garden  $22521052.79    2001-06-08    south africa      8351
# 7      Grocery  $54405380.40    1992-09-16  united kingdom     11538
# 8     Outdoors  $99290004.13    1992-01-11   united states     11787
# 9  Electronics  $44091294.62    2006-07-11  united kingdom      6492
