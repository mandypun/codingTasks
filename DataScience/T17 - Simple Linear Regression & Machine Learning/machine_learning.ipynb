# %% [markdown]
# # Machine Learning

# %% [markdown]
# 1. For each of the following examples describe at least one possible input and
# output. Justify your answers:
# * 1.1 A self-driving car
# * 1.2 Netflix recommendation system
# * 1.3 Signature recognition
# * 1.4 Medical diagnosis

# %% [markdown]
# 1. Answer here
#
# |      | Input(s)    | Output     |
# | ---- | ----------- | ---------  |
# | 1.1  | Real-time images of the road situation:<br />Feeding real-time images as input to recognize obstacles | Classification of obstacles from the real-time images:<br />Predicted by the trained model |
# | 1.2  | View history:<br />Input history to predict the interest of the audience with similar history patterns<br />Age:<br />To find the most interested program in the same age group | Recommended program genre:<br />Predicted genre of interest based on the audience with similar patterns |
# | 1.3  | Signature images:<br />Input to predict the name using the trained model | Recognized name:<br />Name predicted by the training model |
# | 1.4  | Gender, age, weight:<br />Information about the person fed into the model to predict if the person has a disease or not | Probability of having a disease:<br />Predicted probability from the model based on similar patterns |

# %% [markdown]
# 2. For each of the following case studies, determine whether it is appropriate to utilise regression or classification machine learning algorithms. Justify your answers:
# * 2.1 Classifying emails as promotion or social based on their content and metadata.
# * 2.2 Forecasting the stock price of a company based on historical data and market trends.
# * 2.3 Sorting images of animals into different species based on their visual features.
# * 2.4 Predicting the likelihood of a patient having a particular disease based on medical history and diagnostic test results.

# %% [markdown]
# 2. Answer here
# * 2.1: Classification<br>
# Classified emails as promotion or social, which is a category.
# * 2.2: Regression<br>
# Prediction of price is a continuous output value calculated from the model.
# * 2.3: Classification<br>
# Classification of animal species is a category, not a continuous output.
# * 2.4: Regression<br>
# Predicton of probability of fa disease would a continuous output calculated from the model.

# %% [markdown]
# 3. For each of the following real-world problems, determine whether it is appropriate to utilise a supervised or unsupervised machine learning algorithm. Justify your answers:
# * 3.1 Detecting anomalies in a manufacturing process using sensor data without prior knowledge of specific anomaly patterns.
# * 3.2 Predicting customer lifetime value based on historical transaction data and customer demographics.
# * 3.3 Segmenting customer demographics based on their purchase history, browsing behaviour, and preferences.
# * 3.4 Analysing social media posts to categorise them into different themes.

# %% [markdown]
# 3. Answer here
# * 3.1: Unsupervised machine learning algorithm<br>The model is learnt without prior knowledge of specific anomaly patterns, that is not from labelled data.
# * 3.2: Supervised machine learning algorithm<br>The historical transaction data used for tranining has labelled information of the customer lifetime value.
# * 3.3: Unsupervised machine learning algorithm<br>No labelled data or category in the training. The training model should learn the patterns of customer segmentation in the data.
# * 3.4: Supervised machine learning algorithm<br>The model should be trained data with labelled category.

# %% [markdown]
# 4.
# For each of the following real-world problems, determine whether it is appropriate to utilise semi-supervised machine learning algorithms. Justify your answers:
# * 4.1 Predicting fraudulent financial transactions using a dataset where most transactions are labelled as fraudulent or legitimate.
# * 4.2 Analysing customer satisfaction surveys where only a small portion of the data is labelled with satisfaction ratings.
# * 4.3 Identifying spam emails in a dataset where the majority of emails are labelled.
# * 4.4 Predicting the probability of default for credit card applicants based on their complete financial and credit-related information.

# %% [markdown]
# 4. Answer here
# * 4.1: Supervised machine learning algorithm<br>The model is trained with data which is mostly labelled as fraudulent or legitimate.
# * 4.2: Semi-supervised machine learning algorithm<br>Only a small portion of the data is labelled, and additional pattern to be revealled.
# * 4.3: Supervised machine learning algorithm <br>The model is trained with data which is mostly labelled as spam or not.
# * 4.4: Supervised machine learning algorithm <br>The model is trained with data which is mostly labelled, as their financial information is complete.
